# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df1 = pd.read_csv("C:\\Users\\91789\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_13582\\API_SP.POP.TOTL_DS2_en_csv_v2_13582.csv",skiprows=4,encoding='utf-8')

# %%
df1.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2015         2016         2017         2018  \
# ...

# %%
df1.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', 'Unnamed: 68'],
#       dtype='object')

# %%
df1['Unnamed: 68'].unique()
# Out:
# array([nan])

# %%
df1_c=df1.drop(columns=['Unnamed: 68'],errors="ignore")

# %%
df1_c.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
df1_c.fillna(method='ffill',inplace=True)
# Out:
# C:\Users\91789\AppData\Local\Temp\ipykernel_15436\1539090235.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df1_c.fillna(method='ffill',inplace=True)

# %%
df1_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            266 non-null    float64
#  5   1961            266 non-null    float64
#  6   1962            266 non-null    float64
#  7   1963            266 non-null    float64
#  8   1964            266 non-null    float64
#  9   1965            266 non-null    float64
#  10  1966            266 non-null    float64
#  11  1967            266 non-null    float64
#  12  1968            266 non-null    float64
#  13  1969            266 non-null    float64
#  14  1970            266 non-null    float64
#  15  1971            266 non-null    float64
#  16  1972            266 non-null    float64
# ...

# %%
df1_c.shape
# Out:
# (266, 68)

# %%
metadata_indicator_path = "Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_13582.csv"
dfi = pd.read_csv("C:\\Users\\91789\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_13582\\Metadata_Indicator_API_SP.POP.TOTL_DS2_en_csv_v2_13582.csv", encoding="utf-8")

# %%
dfi.head()
# Out:
#   INDICATOR_CODE     INDICATOR_NAME  \
# 0    SP.POP.TOTL  Population, total
#
#                                          SOURCE_NOTE  \
# 0  Total population is based on the de facto defi...
#
#                                  SOURCE_ORGANIZATION  Unnamed: 4
# 0  (1) United Nations Population Division. World ...         NaN

# %%
dfi["Unnamed: 4"].unique()
# Out:
# array([nan])

# %%
dfi_c=dfi.drop(columns=['Unnamed: 4'],errors="ignore").rename(columns={'INDICATOR_CODE':'Indicator Code','INDICATOR_NAME':'Indicator Name','SOURCE_NOTE':'source note','SOURCE_ORGANIZATION':'source organization'})

# %%
dfi_c.head()
# Out:
#   Indicator Code     Indicator Name  \
# 0    SP.POP.TOTL  Population, total
#
#                                          source note  \
# 0  Total population is based on the de facto defi...
#
#                                  source organization
# 0  (1) United Nations Population Division. World ...

# %%
dfm=pd.read_csv("C:\\Users\\91789\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_13582\\Metadata_Country_API_SP.POP.TOTL_DS2_en_csv_v2_13582.csv",encoding="utf-8")

# %%
dfm.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
dfm.shape
# Out:
# (265, 6)

# %%
dfm_c = dfm.drop(columns=["Unnamed: 5"], errors="ignore").rename(columns={
    "Country Code": "Country Code",
    "Region": "Region",
    "IncomeGroup": "Income Group",
    "SpecialNotes": "Special Notes",
    "TableName": "Country Name"
})

# %%
dfm.head(1)
# Out:
#   Country Code                     Region  IncomeGroup SpecialNotes TableName  \
# 0          ABW  Latin America & Caribbean  High income          NaN     Aruba
#
#    Unnamed: 5
# 0         NaN

# %%
dfm_c["Region"].fillna("Unknown", inplace=True)
dfm_c["Income Group"].fillna("Unknown", inplace=True)

# %%
dfm_c.head()
# Out:
#   Country Code                     Region         Income Group  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                    Unknown              Unknown
# 2          AFG                 South Asia           Low income
# 3          AFW                    Unknown              Unknown
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                        Special Notes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                   Country Name
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
df1_c.to_csv("c_df1.csv",index=False)
dfm_c.to_csv("c_dfm_c.csv",index=False)
dfi_c.to_csv("c_dfi_c.csv",index=False)

# %%
d1f = pd.read_csv("C:\\Users\\91789\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_13582\\c_df1.csv")

# %%
d2f=pd.read_csv('c_dfi_c.csv')

# %%
d3f=pd.read_csv("C:\\Users\\91789\\Downloads\\API_SP.POP.TOTL_DS2_en_csv_v2_13582\\c_dfm_c.csv")

# %%
df_merged=pd.merge(d1f,d3f,on='Country Code',how='left')

# %%
d1f.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
d3f.head()
# Out:
#   Country Code                     Region         Income Group  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                    Unknown              Unknown
# 2          AFG                 South Asia           Low income
# 3          AFW                    Unknown              Unknown
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                        Special Notes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                   Country Name
# 0                        Aruba
# 1  Africa Eastern and Southern
# 2                  Afghanistan
# 3   Africa Western and Central
# 4                       Angola

# %%
d2f.head()
# Out:
#   Indicator Code     Indicator Name  \
# 0    SP.POP.TOTL  Population, total
#
#                                          source note  \
# 0  Total population is based on the de facto defi...
#
#                                  source organization
# 0  (1) United Nations Population Division. World ...

# %%
df_merged.head()
# Out:
#                 Country Name_x Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130072080.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2018         2019         2020         2021  \
# ...

# %%
df_merged=pd.merge(d2f, df_merged,on='Indicator Code',how='left')

# %%
df_merged.to_csv("final_merged.csv",index=False)

# %%
final_df=pd.read_csv("final_merged.csv")

# %%
final_df.head()
# Out:
#   Indicator Code   Indicator Name_x  \
# 0    SP.POP.TOTL  Population, total
# 1    SP.POP.TOTL  Population, total
# 2    SP.POP.TOTL  Population, total
# 3    SP.POP.TOTL  Population, total
# 4    SP.POP.TOTL  Population, total
#
#                                          source note  \
# 0  Total population is based on the de facto defi...
# 1  Total population is based on the de facto defi...
# 2  Total population is based on the de facto defi...
# 3  Total population is based on the de facto defi...
# 4  Total population is based on the de facto defi...
#
#                                  source organization  \
# 0  (1) United Nations Population Division. World ...
# 1  (1) United Nations Population Division. World ...
# 2  (1) United Nations Population Division. World ...
# 3  (1) United Nations Population Division. World ...
# 4  (1) United Nations Population Division. World ...
#
#                 Country Name_x Country Code   Indicator Name_y         1960  \
# ...

# %%
year = "2020"
df_year = final_df[["Country Name_x", year]].dropna().nlargest(10, year)

# %%
plt.figure(figsize=(10, 5))
plt.bar(df_year["Country Name_x"], df_year[year], color="skyblue")
plt.xlabel("Country")
plt.ylabel("Population")
plt.title(f"Top 10 Countries by Population in {year}")
plt.xticks(rotation=45)
plt.show()
